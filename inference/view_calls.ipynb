# %%
import pandas as pd

# %%
df = pd.read_json('/iris/u/asap7772/asmr_private/inference/single_layer_outputs.jsonl', lines=True)
df
# Out:
#      query_id                                              query  \
# 0           1  An African author tragically passed away in a ...
# 1           3  The player, born between 1981 and 1984, starte...
# 2           5  There was a global report released by the Worl...
# 3           6  Between 1945 and 1955 inclusive, a particular ...
# 4           7  The headquarters for a company widely reported...
# ..        ...                                                ...
# 825      1262  Set in 19th-century London, the story follows ...
# 826      1263  I am looking for the name of a group of compan...
# 827      1264  Give me the full name of the artist, as of 202...
# 828      1265  As of 2023, what is the first and last name of...
# 829      1266  This foreign individual was born to a business...
#
#                                               response  \
# 0                                            1988-1996
# 1                                             Amr Zaki
# 2    The cover designer of the WHO Global Report on...
# 3                                            3:50 p.m.
# 4
# ..                                                 ...
# 825                                  Storm and Silence
# 826
# 827                                        Alex Turner
# 828
# 829                                 Maryam Tanveer Ali
#
#                             gold_answer  \
# 0                               1988-96
# 1                              Amr Zaki
# 2                        Cristina Ortiz
# 3                               3:50 PM
# 4    Savannah College of Art and Design
# ..                                  ...
# 825                   Storm and Silence
# 826                      PRAN-RFL Group
# 827              Alexander David Turner
# 828                        Kristen Bell
# 829                  Maryam Tanveer Ali
#
#                                             tool_reads  \
# 0    [{'requested_paths': ['99821_brittlepaper_com_...
# 1    [{'requested_paths': ['15312_en_wikipedia_org_...
# 2    [{'requested_paths': ['58586_oialliance_org_wp...
# 3    [{'requested_paths': ['56784_www_palladiummag_...
# 4    [{'requested_paths': ['26646_nvdatabase_swarth...
# ..                                                 ...
# 825  [{'requested_paths': ['1262/42402_en_wikipedia...
# 826  [{'requested_paths': ['85200_futurestartup_com...
# 827  [{'requested_paths': ['86911_www_dailymail_co_...
# 828  [{'requested_paths': ['13284_www_j_14_com_post...
# 829  [{'requested_paths': ['37543_en_wikipedia_org_...
#
#                                       error
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4    'NoneType' object is not subscriptable
# ..                                      ...
# 825                       max_steps_reached
# 826                                     NaN
# 827                                     NaN
# 828                                     NaN
# 829                                     NaN
#
# [830 rows x 6 columns]

# %%
print(df.iloc[0])
# Out:
# query_id                                                       1
# query          An African author tragically passed away in a ...
# response                                               1988-1996
# gold_answer                                              1988-96
# tool_reads     [{'requested_paths': ['99821_brittlepaper_com_...
# error                                                        NaN
# Name: 0, dtype: object

# %%
print(df.iloc[0]['tool_reads'])
# Out:
# [{'requested_paths': ['99821_brittlepaper_com_2020_10_in_memoriam_a_tribute_to_african_authors_who_passed_away_b_4ad3fac757ea.txt'], 'resolved_paths': ['99821_brittlepaper_com_2020_10_in_memoriam_a_tribute_to_african_authors_who_passed_away_b_4ad3fac757ea.txt'], 'errors': []}, {'requested_paths': ['59476_newscentral_africa_mbongeni_ngema_five_other_african_writers_who_died_tragically.txt'], 'resolved_paths': ['59476_newscentral_africa_mbongeni_ngema_five_other_african_writers_who_died_tragically.txt'], 'errors': []}, {'requested_paths': ['59572_news_mak_ac_ug_2018_09_mak_mourns_iconic_literary_alumnus_prof_rubadiri.txt'], 'resolved_paths': ['59572_news_mak_ac_ug_2018_09_mak_mourns_iconic_literary_alumnus_prof_rubadiri.txt'], 'errors': []}, {'requested_paths': ['10264_sevencircumstances_com_2014_04_11_death_of_an_author_goodbye_hennie_aucamp.txt'], 'resolved_paths': ['10264_sevencircumstances_com_2014_04_11_death_of_an_author_goodbye_hennie_aucamp.txt'], 'errors': []}, {'requested_paths': ['3680_www_bbc_com_news_world_africa_68684534.txt'], 'resolved_paths': ['3680_www_bbc_com_news_world_africa_68684534.txt'], 'errors': []}, {'requested_paths': ['79291_ashinedu_art_advocate_medium_com_americanah_by_chimamanda_ngozi_adichie_the_novel_t_6ca56b28d46f.txt'], 'resolved_paths': ['79291_ashinedu_art_advocate_medium_com_americanah_by_chimamanda_ngozi_adichie_the_novel_t_6ca56b28d46f.txt'], 'errors': []}, {'requested_paths': ['2882_meharalit_wordpress_com_2018_08_27_african_literature_through_the_lens_of_ken_walib_be726a60b419.txt'], 'resolved_paths': ['2882_meharalit_wordpress_com_2018_08_27_african_literature_through_the_lens_of_ken_walib_be726a60b419.txt'], 'errors': []}, {'requested_paths': ['62014_ke_linkedin_com_in_ken_walibora_35010362.txt', '62014_ke_linkedin_com_in_ken_walibora_35010362_2.txt', '68543_www_facebook_com_USAfrika_gov_posts_kenyan_prolific_swahili_author_journalist_and_l_7c21f0f040f6.txt', '68543_www_facebook_com_USAfrika_gov_posts_kenyan_prolific_swahili_author_journalist_and_l_7c21f0f040f6_2.txt'], 'resolved_paths': ['62014_ke_linkedin_com_in_ken_walibora_35010362.txt', '62014_ke_linkedin_com_in_ken_walibora_35010362_2.txt', '68543_www_facebook_com_USAfrika_gov_posts_kenyan_prolific_swahili_author_journalist_and_l_7c21f0f040f6.txt', '68543_www_facebook_com_USAfrika_gov_posts_kenyan_prolific_swahili_author_journalist_and_l_7c21f0f040f6_2.txt'], 'errors': []}]
