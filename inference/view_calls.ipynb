# %%
import pandas as pd

# %%
df = pd.read_json('/iris/u/asap7772/asmr_private/inference/single_layer_outputs.jsonl', lines=True)
df
# Out:
#      query_id                                              query  \
# 0           1  An African author tragically passed away in a ...
# 1           1  An African author tragically passed away in a ...
# 2           1  An African author tragically passed away in a ...
# 3           1  An African author tragically passed away in a ...
# 4           3  The player, born between 1981 and 1984, starte...
# ..        ...                                                ...
# 195        81  There is an article about a food made by a min...
# 196        82  As at the beginning of 2021, this individual w...
# 197        82  As at the beginning of 2021, this individual w...
# 198        82  As at the beginning of 2021, this individual w...
# 199        82  As at the beginning of 2021, this individual w...
#
#                                               response       gold_answer  \
# 0                                            1988-1996           1988-96
# ...

# %%
print(df.iloc[0])
# Out:
# query_id                                                       1
# query          An African author tragically passed away in a ...
# response                                               1988-1996
# gold_answer                                              1988-96
# tool_reads     [{'requested_paths': ['2882_meharalit_wordpres...
# sample_idx                                                     0
# error                                                       None
# Name: 0, dtype: object

# %%
print(df.iloc[0]['tool_reads'])
# Out:
# [{'requested_paths': ['2882_meharalit_wordpress_com_2018_08_27_african_literature_through_the_lens_of_ken_walib_be726a60b419.txt', '62014_ke_linkedin_com_in_ken_walibora_35010362.txt', '62014_ke_linkedin_com_in_ken_walibora_35010362_2.txt', '68543_www_facebook_com_USAfrika_gov_posts_kenyan_prolific_swahili_author_journalist_and_l_7c21f0f040f6.txt', '68543_www_facebook_com_USAfrika_gov_posts_kenyan_prolific_swahili_author_journalist_and_l_7c21f0f040f6_2.txt'], 'resolved_paths': ['2882_meharalit_wordpress_com_2018_08_27_african_literature_through_the_lens_of_ken_walib_be726a60b419.txt', '62014_ke_linkedin_com_in_ken_walibora_35010362.txt', '62014_ke_linkedin_com_in_ken_walibora_35010362_2.txt', '68543_www_facebook_com_USAfrika_gov_posts_kenyan_prolific_swahili_author_journalist_and_l_7c21f0f040f6.txt', '68543_www_facebook_com_USAfrika_gov_posts_kenyan_prolific_swahili_author_journalist_and_l_7c21f0f040f6_2.txt'], 'errors': []}, {'requested_paths': ['74874_www_standardmedia_co_ke_articl
# ...
