# %%
import pandas as pd

# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_answers.jsonl', lines=True)
# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_answers_reranked.jsonl', lines=True)
# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_answers_gemini.jsonl', lines=True)
# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_answers_reranked_gemini.jsonl', lines=True)

# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_answers_supponly_gemini.jsonl', lines=True)
# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_answers_supponly_qwen.jsonl', lines=True)

# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_answers_reranked_supponly_qwen.jsonl', lines=True)
# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_answers_reranked_supponly_gemini.jsonl', lines=True)
# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_agentic_answers_gemini.jsonl', lines=True)

# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_agentic_answers_gemini.jsonl', lines=True)
# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_agentic_answers_qwen.jsonl', lines=True)

# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_graph_answers_qwen.jsonl', lines=True)
# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_graph_answers_gemini.jsonl', lines=True)

# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_answers_hybrid_gemini.jsonl', lines=True)
# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_answers_hybrid_qwen.jsonl', lines=True)

# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_answers_qwen.jsonl', lines=True)
# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_answers_gemini.jsonl', lines=True)

# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_autocompaction_answers_gemini.jsonl', lines=True)
# df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_autocompaction_answers_qwen.jsonl', lines=True)

df = pd.read_json('/iris/u/asap7772/asmr_private/retrieval/heldout_answers_moderncolbert_qwen.jsonl', lines=True)
df
# Out:
#     question_id                                           question  \
# 0           618  As of December 2023, in which Formula One Gran...
# 1            22  There is a sport in the world where teams from...
# 2           106  A person hailing from a country in Asia was bo...
# 3          1217  As of 2023, tell me the name of this town base...
# 4             7  The headquarters for a company widely reported...
# 5            62  There is a brand whose products contain a clin...
# 6            90  Provide the full name of a soccer team that ma...
# 7           190  I am looking for an actor who was never marrie...
# 8          1220  A non-English series released before 2017 is k...
# 9          1258  A country is home to a hunter-gatherer society...
# 10           36  A football game took place in the second half ...
# 11           85  There is a book written by an author whose mot...
# 12           89  There is a book published about one of the dea...
# ...

# %%
print(df['correctness'].mean())
# Out:
# 0.38
